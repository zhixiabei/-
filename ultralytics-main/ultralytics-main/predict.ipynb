# %%
from ultralytics import YOLO
yolo = YOLO("./yolov8n.pt",task="detect")
result = yolo(source="F:/ultralytics-main/ultralytics/assets/bus.jpg",save=True)
# Out:
# image 1/1 F:\ultralytics-main\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 144.7ms
# Speed: 9.4ms preprocess, 144.7ms inference, 14.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to F:\ultralytics-main\runs\detect\predict3
